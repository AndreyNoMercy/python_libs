# %% [markdown]
# ### Курсовая работа

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
pd.options.display.max_columns = 25
pd.options.display.max_rows = 100

# %%
train = pd.read_csv('./train.csv')
test = pd.read_csv('./test.csv')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  object
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# # Приведем все признаки к числовым

# %%
train['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
train['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
train['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %%
train['Ecology_2'] = pd.get_dummies(train['Ecology_2'], drop_first=True)

# %%
train['Ecology_3'] = pd.get_dummies(train['Ecology_3'], drop_first=True)

# %%
train['Shops_2'] = pd.get_dummies(train['Shops_2'], drop_first=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  uint8
#  11  Ecology_3      10000 non-null  uint8
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  uint8
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), uint8(3)
# memory usage: 1.3 MB

# %% [markdown]
# # Обработаем выбросы

# %%
train.loc[(train.Rooms > 5) & (train.Square < 100)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 8849  14865           9   10.0  60.871266   38.420681           10.0      3
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 377         22.0       2002   0.090799          1          1        74
# 1454        17.0       2014   0.007122          1          1         1
# 2170         9.0       1969   0.033494          1          1        66
# 8849         2.0       1994   0.161532          1          1        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 377      19083         2           NaN            5       15        1
# 1454       264         0           NaN            0        1        1
# 2170     10573         1        1322.0            3        8        1
# 8849      5648         1          30.0            2        4        1
#
#               Price
# 377   317265.323792
# 1454   78364.616704
# 2170  229661.964416
# 8849  172329.270863

# %%
train.loc[(train.Rooms > 8) & (train.Square < 100), 'Rooms'] = train['Rooms'].mode()[0]

# %%
train.loc[(train.Rooms == 0), ['DistrictId', 'Square', 'LifeSquare', 'Floor', 'HouseFloor', 'KitchenSquare', 'HouseYear', 'Price']]
# Out:
#       DistrictId      Square  LifeSquare  Floor  HouseFloor  KitchenSquare  \
# 1397          27  138.427694  136.215499      4         3.0            0.0
# 1981          27  212.932361  211.231125      2         3.0            0.0
# 2269          27   41.790881         NaN     13         0.0            0.0
# 3911          28   49.483501         NaN     16         0.0            0.0
# 4366           6   81.491446         NaN      4         0.0            0.0
# 4853          27    2.377248    0.873147      1         0.0            0.0
# 6149          88   38.697117   19.345131      9        16.0            9.0
# 8834          27   87.762616   85.125471      5        15.0            0.0
#
#       HouseYear          Price
# 1397       2016  268394.744389
# 1981       2008  302211.260887
# 2269       1977   98129.976788
# 3911       2015  217009.338463
# 4366       1977  212864.799112
# 4853       1977  126596.941798
# 6149       1982  158998.110646
# 8834       1977  219281.918007

# %%
train.loc[(train.Rooms == 0) & (train.KitchenSquare > 0), 'Rooms'] = train['Rooms'].median()

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.887400     56.315775    37.199645
# std     4859.01902     43.587592      0.813626     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000      6.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#           Ecology_2     Ecology_3      Social_1      Social_2      Social_3  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.990300      0.972500     24.687000   5352.157400      8.039200
# std        0.098015      0.163543     17.532614   4006.799803     23.831875
# min        0.000000      0.000000      0.000000    168.000000      0.000000
# 25%        1.000000      1.000000      6.000000   1564.000000      0.000000
# 50%        1.000000      1.000000     25.000000   5285.000000      2.000000
# 75%        1.000000      1.000000     36.000000   7227.000000      5.000000
# max        1.000000      1.000000     74.000000  19083.000000    141.000000
#
#        Healthcare_1   Helthcare_2       Shops_1       Shops_2          Price
# count   5202.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    1142.904460      1.319500      4.231300      0.917500  214138.857399
# std     1021.517264      1.493601      4.806341      0.275139   92872.293865
# min        0.000000      0.000000      0.000000      0.000000   59174.778028
# 25%      350.000000      0.000000      1.000000      1.000000  153872.633942
# 50%      900.000000      1.000000      3.000000      1.000000  192269.644879
# 75%     1548.000000      2.000000      6.000000      1.000000  249135.462171
# max     4849.000000      6.000000     23.000000      1.000000  633233.466570

# %%
train.loc[(train.Square > 150) & (train.Square > train.LifeSquare * 2)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 5087  15947         129    4.0  185.906396   84.830074           31.0      5
# 6451   3914          24    4.0  155.930023   76.831293           15.0      6
# 7201   3233         129    4.0  186.692602   87.487080           32.0      3
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 5087         3.0       2015   0.020741          1          1        24
# 6451        22.0       2012   0.111627          1          1        50
# 7201         3.0       2011   0.020741          1          1        24
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 5087      5613         5        1340.0            2        5        1
# 6451     12238         8        1970.0            2        3        1
# 7201      5613         5        1340.0            2        5        1
#
#               Price
# 5087  340273.238253
# 6451  559886.965348
# 7201  423443.464367

# %%
train.loc[(train.Square < 5) & (train.LifeSquare > 6)]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 3280  10527          27    1.0  4.380726   40.805837            1.0     10
# 8030  13265           1    3.0  4.823679   79.767964            0.0      6
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 3280        17.0       2013   0.211401          1          1         9
# 8030        17.0       1977   0.007122          1          1         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 3280      1892         0           NaN            0        1        1
# 8030       264         0           NaN            0        1        1
#
#               Price
# 3280   97560.720383
# 8030  237716.681261

# %%
train.loc[(train.Square < 5) & (train.LifeSquare > 70), 'Square'] = 124

# %%
train.loc[(train.Square < 5) & (train.LifeSquare > 6), 'Square'] = 43.80726

# %%
train.loc[(train.Square * 1.2 < train.LifeSquare) & (train.LifeSquare > 150)]
# Out:
#          Id  DistrictId  Rooms     Square   LifeSquare  KitchenSquare  Floor  \
# 590   14990          23    2.0  48.449873   263.542020            5.0      6
# 4328  16550          27    3.0  81.694417  7480.592129            1.0      9
# 6332   8961          27    1.0  33.398983   164.153360            6.0      3
# 8437  15886          85    3.0  78.059331   461.463614           10.0     12
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 590          5.0       1972   0.075779          1          1         6
# 4328        17.0       2016   0.017647          1          1         2
# 6332         5.0       1965   0.211401          1          1         9
# 8437        16.0       1998   0.037178          1          1        52
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 590       1437         3           NaN            0        2        1
# 4328       469         0           NaN            0        0        1
# 6332      1892         0           NaN            0        1        1
# 8437     11217         1        2300.0            1        7        1
#
#               Price
# 590   141780.231857
# 4328  217357.492366
# 6332  104891.073757
# 8437  394253.299978

# %%
train.loc[(train.Square * 1.2 < train.LifeSquare) & (train.LifeSquare > 150), 'LifeSquare'] = train.loc[(train.Square * 1.2 < train.LifeSquare) & (train.LifeSquare > 150), 'LifeSquare'] / 10

# %%
train.loc[(train.Square * 1.2 < train.LifeSquare) & (train.LifeSquare > 150), 'LifeSquare'] = train.loc[(train.Square * 1.2 < train.LifeSquare) & (train.LifeSquare > 150), 'LifeSquare'] / 10

# %%
train.loc[(train.LifeSquare < 8) & (train.KitchenSquare > 1)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1800  13113          27    1.0  37.805231    2.228592           11.0      6
# 4588    448          48    1.0  41.186904    1.626502           41.0      2
# 6036  12666          34    2.0  60.603363    2.400832           58.0     14
# 9602   5112           6    2.0  63.591740    0.795539           10.0     17
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 1800         0.0       2015   0.017647          1          1         2
# 4588         1.0       1977   0.041125          1          1        46
# 6036        22.0       1977   0.069753          1          1        53
# 9602        17.0       2014   0.243205          1          1         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 1800       469         0           NaN            0        0        1
# 4588      9515         5           NaN            1       10        1
# 6036     13670         4           NaN            1       11        1
# 9602      1564         0         540.0            0        0        1
#
#               Price
# 1800  137402.092529
# 4588  216882.265408
# 6036  261733.472106
# 9602  174741.998061

# %%
for el in [448, 12666]:
    x1 = train.loc[(train.Id == el), 'LifeSquare']
    x2 = train.loc[(train.Id == el), 'KitchenSquare']
    train.loc[(train.Id == el), 'LifeSquare'] = x2
    train.loc[(train.Id == el), 'KitchenSquare'] = x1
    print(x1, x2)
# Out:
# 4588    1.626502
# Name: LifeSquare, dtype: float64 4588    41.0
# Name: KitchenSquare, dtype: float64
# 6036    2.400832
# Name: LifeSquare, dtype: float64 6036    58.0
# Name: KitchenSquare, dtype: float64

# %%
x1 = train.loc[(train.Id == 5112), 'LifeSquare'] * 100
x2 = train.loc[(train.Id == 5112), 'Square']
train.loc[(train.Id == 5112), 'LifeSquare'] = x2
train.loc[(train.Id == 5112), 'Square'] = x1
print(train.loc[(train.Id == 5112)])
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 9602  5112           6    2.0  79.553947    63.59174           10.0     17
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 9602        17.0       2014   0.243205          1          1         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 9602      1564         0         540.0            0        0        1
#
#               Price
# 9602  174741.998061

# %%
train.loc[(train.Id == 13113), 'LifeSquare'] = train.loc[(train.Id == 13113), 'LifeSquare'] * 10

# %%
train.loc[train.Square < train.LifeSquare]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 28     8054          23    1.0   42.530043   43.967759            1.0      3
# 44    10521          38    3.0  104.211396  106.340403            0.0     20
# 52     2301           1    2.0   61.400054   65.224603            0.0     17
# 123    8753          25    3.0   85.952306   89.803753            1.0      4
# 153    9870          62    1.0   51.831473   53.491301            1.0      5
# ...     ...         ...    ...         ...         ...            ...    ...
# 9884     41          30    2.0   59.015896   59.439082           12.0      5
# 9889  12918          23    2.0   51.440463   53.134243           51.0      3
# 9895   2737          27    3.0  123.430072  125.806981          123.0      5
# 9902  14001          73    1.0   44.098768   44.267551            1.0      7
# 9910  16568          27    4.0  200.334539  201.627361           25.0      1
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 28           9.0       2014   0.034656          1          1         0
# 44           0.0       2017   0.060753          1          1        15
# 52          22.0       2016   0.007122          1          1         1
# 123          3.0       2017   0.069753          1          1        53
# 153          1.0       2015   0.072158          1          1         2
# ...          ...        ...        ...        ...        ...       ...
# 9884         5.0       2016   0.000078          1          1        22
# 9889        17.0       2017   0.005767          1          1         1
# 9895        10.0       2015   0.017647          1          1         2
# 9902        24.0       2014   0.042032          1          1        37
# 9910         2.0       2013   0.041116          1          1        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 28         168         0           NaN            0        0        1
# 44        2787         2         520.0            0        7        1
# 52         264         0           NaN            0        1        1
# 123      13670         4           NaN            1       11        1
# 153        629         1           NaN            0        0        0
# ...        ...       ...           ...          ...      ...      ...
# 9884      6398       141        1046.0            3       23        1
# 9889       388         0           NaN            0        0        1
# 9895       469         0           NaN            0        0        1
# 9902      6856        84        1940.0            2        5        1
# 9910     14892         4           NaN            1        4        1
#
#               Price
# 28     95338.198549
# 44    435462.048070
# 52    199215.452229
# 123   309688.592681
# 153   131797.472284
# ...             ...
# 9884  126281.142781
# 9889   88150.012510
# 9895  234194.837047
# 9902  381937.404161
# 9910  528560.506016
#
# [476 rows x 20 columns]

# %%
train.loc[train.Square * 1.2 <  train.LifeSquare]
# Out:
#          Id  DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 212    1748          88    2.0  5.497061   67.628717            1.0     24
# 1608  10202           6    1.0  2.596351    4.604943            1.0      3
# 4900   4504          27    3.0  4.390331    5.610772            1.0      8
# 6392  14786           1    1.0  1.136859    4.525736            1.0      3
# 8283  15744          34    1.0  1.988943    2.642219            1.0     21
# 9294   6782          45    1.0  2.954309    5.257278            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 212         22.0       1977   0.127376          1          1        43
# 1608        25.0       2014   0.243205          1          1         5
# 4900        19.0       2016   0.211401          1          1         9
# 6392         1.0       1977   0.007122          1          1         1
# 8283         4.0       1977   0.069753          1          1        53
# 9294         1.0       1977   0.195781          1          1        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 212       8429         3           NaN            3        9        1
# 1608      1564         0         540.0            0        0        1
# 4900      1892         0           NaN            0        1        1
# 6392       264         0           NaN            0        1        1
# 8283     13670         4           NaN            1       11        1
# 9294      5212         6           NaN            3        2        1
#
#               Price
# 212   412511.088764
# 1608  137597.601458
# 4900  161379.067034
# 6392  181434.825589
# 8283  458378.777006
# 9294  438005.182323

# %%
def change_cols(place, col_1, col_2):
    for el in place:
        x1 = train.loc[(train.Id == el), col_1]
        x2 = train.loc[(train.Id == el), col_2]
        train.loc[(train.Id == el), col_1] = x2
        train.loc[(train.Id == el), col_2] = x1

# %%
train.loc[(train.Id == 1748), 'Square'] = train.loc[(train.Id == 1748), 'Square'] * 10

# %%
change_cols(train.loc[train.Square < train.LifeSquare, 'Id'].values, 'Square', 'LifeSquare')

# %%
train.loc[train.KitchenSquare > 200, 'KitchenSquare'] = train['KitchenSquare'].median()

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.887400     56.416989    36.081818
# std     4859.01902     43.587592      0.813626     21.065636    19.353397
# min        0.00000      0.000000      0.000000      2.377248     0.370619
# 25%     4169.50000     20.000000      1.000000     41.866858    22.783354
# 50%     8394.50000     36.000000      2.000000     52.619610    32.781260
# 75%    12592.50000     75.000000      2.000000     66.002322    45.048935
# max    16798.00000    209.000000      6.000000    641.065193   638.163193
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        5.866603      8.526700     12.609400  3.990166e+03      0.118858
# std         5.135976      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max       123.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#           Ecology_2     Ecology_3      Social_1      Social_2      Social_3  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.990300      0.972500     24.687000   5352.157400      8.039200
# std        0.098015      0.163543     17.532614   4006.799803     23.831875
# min        0.000000      0.000000      0.000000    168.000000      0.000000
# 25%        1.000000      1.000000      6.000000   1564.000000      0.000000
# 50%        1.000000      1.000000     25.000000   5285.000000      2.000000
# 75%        1.000000      1.000000     36.000000   7227.000000      5.000000
# max        1.000000      1.000000     74.000000  19083.000000    141.000000
#
#        Healthcare_1   Helthcare_2       Shops_1       Shops_2          Price
# count   5202.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    1142.904460      1.319500      4.231300      0.917500  214138.857399
# std     1021.517264      1.493601      4.806341      0.275139   92872.293865
# min        0.000000      0.000000      0.000000      0.000000   59174.778028
# 25%      350.000000      0.000000      1.000000      1.000000  153872.633942
# 50%      900.000000      1.000000      3.000000      1.000000  192269.644879
# 75%     1548.000000      2.000000      6.000000      1.000000  249135.462171
# max     4849.000000      6.000000     23.000000      1.000000  633233.466570

# %%
train.loc[(train.Floor > train.HouseFloor) & (train.HouseFloor == 0)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7     11993          74    2.0   80.312926         NaN            0.0     14
# 23     6641          54    3.0  118.907612         NaN            0.0      2
# 26     4378          27    3.0  106.958871    0.641822            0.0     17
# 39     9371          23    2.0   60.503248         NaN            0.0     16
# 44    10521          38    3.0  106.340403  104.211396            0.0     20
# ...     ...         ...    ...         ...         ...            ...    ...
# 9707  12302          30    1.0   48.307844   46.072913            0.0      4
# 9769   9384          59    3.0   98.607328         NaN            0.0     14
# 9878  11441          62    2.0   72.453232   71.985335            0.0      5
# 9908   3171          62    1.0   35.873961         NaN            0.0     25
# 9944  16160          27    2.0   60.396765         NaN            0.0     10
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 7            0.0       1977   0.075779          1          1         6
# 23           0.0       1977   0.006076          1          1        30
# 26           0.0       2018   0.072158          1          1         2
# 39           0.0       1977   0.034656          1          1         0
# 44           0.0       2017   0.060753          1          1        15
# ...          ...        ...        ...        ...        ...       ...
# 9707         0.0       1977   0.000078          1          1        22
# 9769         0.0       1977   0.019509          1          1        37
# 9878         0.0       1977   0.072158          1          1         2
# 9908         0.0       1977   0.072158          1          1         2
# 9944         0.0       1977   0.072158          1          1         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 7         1437         3           NaN            0        2        1
# 23        5285         0         645.0            6        6        1
# 26         629         1           NaN            0        0        0
# 39         168         0           NaN            0        0        1
# 44        2787         2         520.0            0        7        1
# ...        ...       ...           ...          ...      ...      ...
# 9707      6398       141        1046.0            3       23        1
# 9769      7687        11         176.0            5        5        1
# 9878       629         1           NaN            0        0        0
# 9908       629         1           NaN            0        0        0
# 9944       629         1           NaN            0        0        0
#
#               Price
# 7     221244.156664
# 23    571069.052600
# 26    337299.867936
# 39    229778.057902
# 44    435462.048070
# ...             ...
# 9707  161403.094034
# 9769  492700.257473
# 9878  158841.624543
# 9908  134379.130962
# 9944  211810.600728
#
# [269 rows x 20 columns]

# %%
change_cols(train.loc[(train.Floor > train.HouseFloor) & (train.HouseFloor == 0), 'Id'].values, 'Floor', 'HouseFloor')

# %%
import random
wrong_floor = train.loc[train.Floor > train.HouseFloor].index
train.loc[wrong_floor, 'Floor'] = train.loc[wrong_floor, 'HouseFloor'].apply(lambda x: random.randint(1, x))

# %%
train.loc[train.HouseYear > 2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0    9.0
# 4189  11607         147    2.0  44.791836   28.360393            5.0    4.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330          1          1        30
# 4189         9.0       4968   0.319809          1          1        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 1497      6141        10         262.0            3        6        1
# 4189      4756        16        2857.0            5        8        1
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
train.loc[train.HouseYear > 5020, 'HouseYear'] = 2005

# %%
train.loc[train.HouseYear > 2020, 'HouseYear'] = 1968

# %%
train.loc[train.KitchenSquare > 50]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 227   16395           2    3.0   79.722243   44.731219           72.0   12.0
# 1369   2371          27    2.0   68.841073   64.234956           66.0    2.0
# 1455  12507          54    2.0   79.810535   79.578961           78.0   10.0
# 1860   4265         161    2.0   53.216778   32.644859           53.0    7.0
# 2916  12390          72    3.0   99.323558   97.490674           96.0   22.0
# 2969   7441          62    3.0  114.734473  112.589083          112.0    3.0
# 4079   6508          23    2.0   67.146049   33.959154           63.0    5.0
# 4110    299          27    2.0   66.787523   64.616662           60.0   14.0
# 4651  12552          58    3.0  116.405693  113.109653          112.0    3.0
# 5149  13703          42    1.0   38.071692   19.723548           73.0    9.0
# 5162  11739          27    2.0   61.070298   59.845092           58.0    8.0
# 5888  16593          52    2.0   64.859242         NaN           62.0   15.0
# 5904    673          27    1.0   54.418214   51.498581           51.0   10.0
# 6240   4966          96    3.0   78.445675   47.146757           75.0    9.0
# 7088   6569          27    1.0   38.220258   18.716856           84.0    4.0
# 8232   7162          34    2.0   57.510395   56.738764           54.0    8.0
# 9889  12918          23    2.0   53.134243   51.440463           51.0    3.0
# 9895   2737          27    3.0  125.806981  123.430072          123.0    5.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 227         16.0       1987   0.130618          1          1        39
# 1369         2.0       2014   0.017647          1          1         2
# 1455        15.0       2014   0.006076          1          1        30
# 1860        17.0       1994   0.000699          1          1        14
# 2916        25.0       2019   0.210473          1          1        11
# 2969         3.0       2015   0.072158          1          1         2
# 4079        17.0       2019   0.034656          1          1         0
# 4110        20.0       2015   0.017647          1          1         2
# 4651         3.0       2016   0.437885          1          1        23
# 5149        10.0       2006   0.158249          1          1        21
# 5162        17.0       2016   0.072158          1          1         2
# 5888        17.0       1977   0.371149          1          1        34
# 5904        17.0       2017   0.072158          1          1         2
# 6240        12.0       1977   0.041116          1          1        53
# 7088        17.0       2018   0.011654          1          1         4
# 8232        25.0       2016   0.069753          1          1        53
# 9889        17.0       2017   0.005767          1          1         1
# 9895        10.0       2015   0.017647          1          1         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 227      10418         9         900.0            1        9        1
# 1369       469         0           NaN            0        0        1
# 1455      5285         0         645.0            6        6        1
# 1860      3369        24        4129.0            0        3        1
# 2916      2398         2        1994.0            3        0        1
# 2969       629         1           NaN            0        0        0
# 4079       168         0           NaN            0        0        1
# 4110       469         0           NaN            0        0        1
# 4651      5735         3        1084.0            0        5        1
# 5149      5731         0           NaN            1        0        1
# 5162       629         1           NaN            0        0        0
# 5888      7065         1         750.0            2        5        1
# 5904       629         1           NaN            0        0        0
# 6240     14892         4           NaN            1        4        1
# 7088       915         0           NaN            0        0        1
# 8232     13670         4           NaN            1       11        1
# 9889       388         0           NaN            0        0        1
# 9895       469         0           NaN            0        0        1
#
#               Price
# 227   370148.625285
# 1369  189244.249909
# 1455  438708.707579
# 1860  261125.669724
# 2916  445074.956552
# 2969  315245.521059
# 4079  193130.585871
# 4110  179466.094235
# 4651  296165.936689
# 5149  160488.033165
# 5162  212188.959537
# 5888  185993.474671
# 5904  133273.635012
# 6240  290354.484070
# 7088   99079.960518
# 8232  244220.621495
# 9889   88150.012510
# 9895  234194.837047

# %% [markdown]
# # Столбцы LifeSquare & Healthcare 1 имеют пропуски, заполним их

# %%
train.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.887400     56.416989    36.081818
# std     4859.01902     43.587592      0.813626     21.065636    19.353397
# min        0.00000      0.000000      0.000000      2.377248     0.370619
# 25%     4169.50000     20.000000      1.000000     41.866858    22.783354
# 50%     8394.50000     36.000000      2.000000     52.619610    32.781260
# 75%    12592.50000     75.000000      2.000000     66.002322    45.048935
# max    16798.00000    209.000000      6.000000    641.065193   638.163193
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean        5.866603      7.206500     12.852200   1984.865700      0.118858
# std         5.135976      5.147301      6.536821     18.411517      0.119025
# min         0.000000      0.000000      1.000000   1910.000000      0.000000
# 25%         1.000000      3.000000      9.000000   1974.000000      0.017647
# 50%         6.000000      6.000000     14.000000   1977.000000      0.075424
# 75%         9.000000     10.000000     17.000000   2001.000000      0.195781
# max       123.000000     42.000000    117.000000   2020.000000      0.521867
#
#           Ecology_2     Ecology_3      Social_1      Social_2      Social_3  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.990300      0.972500     24.687000   5352.157400      8.039200
# std        0.098015      0.163543     17.532614   4006.799803     23.831875
# min        0.000000      0.000000      0.000000    168.000000      0.000000
# 25%        1.000000      1.000000      6.000000   1564.000000      0.000000
# 50%        1.000000      1.000000     25.000000   5285.000000      2.000000
# 75%        1.000000      1.000000     36.000000   7227.000000      5.000000
# max        1.000000      1.000000     74.000000  19083.000000    141.000000
#
#        Healthcare_1   Helthcare_2       Shops_1       Shops_2          Price
# count   5202.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    1142.904460      1.319500      4.231300      0.917500  214138.857399
# std     1021.517264      1.493601      4.806341      0.275139   92872.293865
# min        0.000000      0.000000      0.000000      0.000000   59174.778028
# 25%      350.000000      0.000000      1.000000      1.000000  153872.633942
# 50%      900.000000      1.000000      3.000000      1.000000  192269.644879
# 75%     1548.000000      2.000000      6.000000      1.000000  249135.462171
# max     4849.000000      6.000000     23.000000      1.000000  633233.466570

# %%
train.loc[(train.LifeSquare.isna()) & (train.HouseYear != 1977)].describe()
# Out:
#                  Id  DistrictId       Rooms      Square  LifeSquare  \
# count    256.000000  256.000000  256.000000  256.000000         0.0
# mean    8467.980469   34.761719    1.773438   59.709943         NaN
# std     4869.124747   28.411297    0.784305   19.729941         NaN
# min       32.000000    0.000000    0.000000   27.245731         NaN
# 25%     4208.500000   23.000000    1.000000   42.569331         NaN
# 50%     8534.000000   30.000000    2.000000   57.355835         NaN
# 75%    12425.750000   48.000000    2.000000   73.781110         NaN
# max    16753.000000  169.000000    3.000000  136.727224         NaN
#
#        KitchenSquare       Floor  HouseFloor    HouseYear   Ecology_1  \
# count     256.000000  256.000000  256.000000   256.000000  256.000000
# mean        2.882812    8.257812   14.593750  2015.855469    0.084271
# std         3.760728    6.065326    7.173959     1.354227    0.106948
# min         0.000000    0.000000    1.000000  2012.000000    0.000000
# 25%         1.000000    3.000000   12.000000  2015.000000    0.007122
# 50%         1.000000    7.000000   17.000000  2016.000000    0.041125
# 75%         1.000000   13.000000   19.000000  2017.000000    0.090140
# max        15.000000   25.000000   27.000000  2019.000000    0.437885
#
#         Ecology_2  Ecology_3    Social_1      Social_2    Social_3  \
# count  256.000000      256.0  256.000000    256.000000  256.000000
# mean     0.996094        1.0   16.957031   4120.582031   26.781250
# std      0.062500        0.0   16.054384   3844.367687   53.250564
# min      0.000000        1.0    0.000000    168.000000    0.000000
# 25%      1.000000        1.0    2.000000    629.000000    0.000000
# 50%      1.000000        1.0   18.000000   3594.000000    1.000000
# 75%      1.000000        1.0   23.000000   6398.000000    6.000000
# max      1.000000        1.0   53.000000  13670.000000  141.000000
#
#        Healthcare_1  Helthcare_2     Shops_1     Shops_2          Price
# count    107.000000   256.000000  256.000000  256.000000     256.000000
# mean     901.757009     1.082031    6.371094    0.890625  201883.586926
# std      625.047800     1.333251    8.407221    0.312721  100361.568994
# min        0.000000     0.000000    0.000000    0.000000   64927.358711
# 25%      540.000000     0.000000    0.000000    1.000000  131167.219758
# 50%     1046.000000     0.000000    2.000000    1.000000  180626.175902
# 75%     1046.000000     3.000000   11.000000    1.000000  234140.209759
# max     3855.000000     6.000000   23.000000    1.000000  633233.466570

# %% [markdown]
# Чуть больше 10 процентов обьектов "не имеющих" жилой площади были построны не в 1977 году.
# Все дома "не имеющие" жилой площади не отличатся от других, судя по describe
# Будем считать, что "отутсвие" жилой площади это ошибка в данных.
# Заполним пропуски умножив на среднее между отношениями ср. арифметических и медианнан площади и жил. площади

# %%
train.loc[~train['LifeSquare'].isna()].describe()
# Out:
#                 Id   DistrictId        Rooms       Square   LifeSquare  \
# count   7887.00000  7887.000000  7887.000000  7887.000000  7887.000000
# mean    8417.37099    56.670217     1.916445    55.362590    36.081818
# std     4864.99023    45.348356     0.823964    20.435518    19.353397
# min        0.00000     0.000000     0.000000     2.377248     0.370619
# 25%     4222.50000    22.000000     1.000000    41.305545    22.783354
# 50%     8419.00000    46.000000     2.000000    50.957360    32.781260
# 75%    12655.00000    88.000000     3.000000    64.888720    45.048935
# max    16798.00000   209.000000     6.000000   641.065193   638.163193
#
#        KitchenSquare        Floor  HouseFloor    HouseYear    Ecology_1  \
# count    7887.000000  7887.000000  7887.00000  7887.000000  7887.000000
# mean        7.067583     7.134145    12.49702  1985.711804     0.122521
# std         4.962873     4.886203     6.30815    19.577849     0.120083
# min         0.000000     0.000000     1.00000  1910.000000     0.000000
# 25%         5.000000     3.000000     9.00000  1971.000000     0.025609
# 50%         7.000000     6.000000    12.00000  1979.000000     0.081943
# 75%         9.000000    10.000000    17.00000  2004.000000     0.194489
# max       123.000000    42.000000   117.00000  2020.000000     0.521867
#
#          Ecology_2    Ecology_3     Social_1      Social_2     Social_3  \
# count  7887.000000  7887.000000  7887.000000   7887.000000  7887.000000
# mean      0.988462     0.965132    28.480284   6097.788006     7.272981
# std       0.106800     0.183456    16.651660   3908.899268    19.682824
# min       0.000000     0.000000     0.000000    168.000000     0.000000
# 25%       1.000000     1.000000    19.000000   3681.000000     1.000000
# 50%       1.000000     1.000000    28.000000   5664.000000     2.000000
# 75%       1.000000     1.000000    38.000000   7759.000000     5.000000
# max       1.000000     1.000000    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1      Shops_2          Price
# count   4457.000000  7887.000000  7887.000000  7887.000000    7887.000000
# mean    1211.382769     1.521491     4.531254     0.930519  223409.768022
# std     1068.252389     1.517006     4.430431     0.254287   94951.990144
# min       30.000000     0.000000     0.000000     0.000000   59174.778028
# 25%      325.000000     0.000000     1.000000     1.000000  162060.719310
# 50%     1015.000000     1.000000     4.000000     1.000000  200014.336149
# 75%     1894.000000     3.000000     6.000000     1.000000  262296.554087
# max     4849.000000     6.000000    23.000000     1.000000  625678.644994

# %%
train['LifeSquare'].fillna(train['Square']*0.67348861, inplace=True)

# %%
train.loc[(train.Healthcare_1 == 0), 'DistrictId'].value_counts()
# Out:
# 23    1
# Name: DistrictId, dtype: int64

# %%
train.loc[(train.DistrictId == 23), 'DistrictId'].value_counts()
# Out:
# 23    565
# Name: DistrictId, dtype: int64

# %%
train.loc[(train.Healthcare_1 == 0), 'Healthcare_1'] = np.nan

# %%
healthcare1_mode = train[~train['Healthcare_1'].isna()]['Healthcare_1'].mode()[0]
for i in range(train['DistrictId'].max()):
    if train.loc[(train['DistrictId'] == i), 'Healthcare_1'].value_counts().empty:
        health_mode = healthcare1_mode
    else:
        health_mode = train.loc[((train.DistrictId == i)&(~train.DistrictId.isna())), 'Healthcare_1'].mode()[0]
    train.loc[((train['Healthcare_1'].isnull())&(train['DistrictId'] == i)), 'Healthcare_1'] = health_mode
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     10000 non-null  float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  float64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  uint8
#  11  Ecology_3      10000 non-null  uint8
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   10000 non-null  float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  uint8
#  19  Price          10000 non-null  float64
# dtypes: float64(9), int64(8), uint8(3)
# memory usage: 1.3 MB

# %%
X = train.iloc[:, 2:-1]
y = pd.Series(train['Price'])
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rooms          10000 non-null  float64
#  1   Square         10000 non-null  float64
#  2   LifeSquare     10000 non-null  float64
#  3   KitchenSquare  10000 non-null  float64
#  4   Floor          10000 non-null  float64
#  5   HouseFloor     10000 non-null  float64
#  6   HouseYear      10000 non-null  int64
#  7   Ecology_1      10000 non-null  float64
#  8   Ecology_2      10000 non-null  uint8
#  9   Ecology_3      10000 non-null  uint8
#  10  Social_1       10000 non-null  int64
#  11  Social_2       10000 non-null  int64
#  12  Social_3       10000 non-null  int64
#  13  Healthcare_1   10000 non-null  float64
#  14  Helthcare_2    10000 non-null  int64
#  15  Shops_1        10000 non-null  int64
#  16  Shops_2        10000 non-null  uint8
# dtypes: float64(8), int64(6), uint8(3)
# memory usage: 1.1 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)

# %%
X_test_scaled = scaler.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
parameters = [{'n_estimators': [480, 700],
'max_features': np.arange(3, 7),
'max_depth': np.arange(13, 17)}]

# %%
forest_best = RandomForestRegressor(max_depth=15, max_features=4, n_estimators=600, random_state=42)

# %%
forest_best.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=15, max_features=4, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=600, n_jobs=None, oob_score=False,
#                       random_state=42, verbose=0, warm_start=False)

# %%
forest_best.score(X_test_scaled, y_test)
# Out:
# 0.7282384085985407

# %% [markdown]
# Пробовал ГриидСеарч для случ леса
# [{'n_estimators': [5, 700],
# 'max_features': np.arange(3, 20),
# 'max_depth': np.arange(7, 25)}]
# # непонятно почему то при задании пересекающихся диапозонов
# # бест парамс с разными значениями внутри этих диапзонов??????

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
parameters_2 = [{'n_estimators': [500, 600],
'max_features': np.arange(1, 5),
'max_depth': np.arange(5, 12)}]

# %%
boost_best = GradientBoostingRegressor(max_depth=7, max_features=2, n_estimators=550, random_state=23)

# %%
boost_best.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=7,
#                           max_features=2, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=550,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=23, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
boost_best.score(X_test_scaled, y_test)
# Out:
# 0.733573280774759

# %%
test
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0       725          58    2.0  49.882643   33.432782            6.0      6
# 1     15856          74    2.0  69.263183         NaN            1.0      6
# 2      5480         190    1.0  13.597819   15.948246           12.0      2
# 3     15664          47    2.0  73.046609   51.940842            9.0     22
# 4     14275          27    1.0  47.527111   43.387569            1.0     17
# ...     ...         ...    ...        ...         ...            ...    ...
# 4995   8180          11    3.0  67.133911   50.809797            6.0      5
# 4996   4695           1    1.0  40.198472   21.807061           10.0     12
# 4997   5783          12    3.0  77.842178   48.282625            9.0     23
# 4998   4780          62    2.0  81.305222         NaN            0.0      4
# 4999  12504          30    2.0  60.555693         NaN            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0           14.0       1972   0.310199         B         B        11
# 1            1.0       1977   0.075779         B         B         6
# 2            5.0       1909   0.000000         B         B        30
# 3           22.0       2007   0.101872         B         B        23
# 4           17.0       2017   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 4995         9.0       1973   0.000170         B         B        36
# 4996        17.0       2017   0.007122         B         B         1
# 4997        22.0       1989   0.090799         B         B        74
# 4998         0.0       1977   0.072158         B         B         2
# 4999        17.0       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         2748         1           NaN            0        0       B
# 1         1437         3           NaN            0        2       B
# 2         7538        87        4702.0            5        5       B
# 3         4583         3           NaN            3        3       B
# 4          629         1           NaN            0        0       A
# ...        ...       ...           ...          ...      ...     ...
# 4995      5992         0           NaN            1        1       B
# 4996       264         0           NaN            0        1       B
# 4997     19083         2           NaN            5       15       B
# 4998       629         1           NaN            0        0       A
# 4999      6398       141        1046.0            3       23       B
#
# [5000 rows x 19 columns]

# %%
test_id = test.iloc[:, 0]
test_id.head()
# Out:
# 0      725
# 1    15856
# 2     5480
# 3    15664
# 4    14275
# Name: Id, dtype: int64

# %%
test['Ecology_2'].value_counts()
# Out:
# B    4952
# A      48
# Name: Ecology_2, dtype: int64

# %%
test['Ecology_3'].value_counts()
# Out:
# B    4851
# A     149
# Name: Ecology_3, dtype: int64

# %%
test['Shops_2'].value_counts()
# Out:
# B    4588
# A     412
# Name: Shops_2, dtype: int64

# %%
test['Ecology_2'] = pd.get_dummies(test['Ecology_2'], drop_first=True)

# %%
test['Ecology_3'] = pd.get_dummies(test['Ecology_3'], drop_first=True)

# %%
test['Shops_2'] = pd.get_dummies(test['Shops_2'], drop_first=True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   uint8
#  11  Ecology_3      5000 non-null   uint8
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
#  17  Shops_1        5000 non-null   int64
#  18  Shops_2        5000 non-null   uint8
# dtypes: float64(7), int64(9), uint8(3)
# memory usage: 639.8 KB

# %% [markdown]
# # Обработаем выбросы

# %%
test.loc[(test.Rooms > 5) & (test.Square < 100)]
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3398  1435         111   17.0  52.866107   32.528342            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 3398        17.0       1987   0.093443          1          1        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# 3398      4635         5        3300.0            2        4        1

# %%
test.loc[(test.Rooms == 0) & (test.KitchenSquare > 0), 'Rooms'] = test['Rooms'].median()

# %%
test.describe()
# Out:
#                  Id   DistrictId       Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.00000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.91040    56.449500    36.158810
# std     4832.674037    44.179466     0.83816    19.092787    17.825287
# min        1.000000     0.000000     0.00000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.00000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.00000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.00000    66.285129    45.174091
# max    16795.000000   212.000000    17.00000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# min         0.000000     1.000000     0.000000  1908.000000     0.000000
# 25%         1.000000     4.000000     9.000000  1973.000000     0.019509
# 50%         6.000000     7.000000    12.000000  1977.000000     0.072158
# 75%         9.000000    12.000000    17.000000  2000.000000     0.195781
# max       620.000000    78.000000    99.000000  2020.000000     0.521867
#
#          Ecology_2    Ecology_3     Social_1      Social_2     Social_3  \
# count  5000.000000  5000.000000  5000.000000   5000.000000  5000.000000
# mean      0.990400     0.970200    24.933800   5406.900000     8.262600
# std       0.097518     0.170052    17.532202   4026.614773    23.863762
# min       0.000000     0.000000     0.000000    168.000000     0.000000
# 25%       1.000000     1.000000     6.000000   1564.000000     0.000000
# 50%       1.000000     1.000000    25.000000   5285.000000     2.000000
# 75%       1.000000     1.000000    36.000000   7287.000000     5.000000
# max       1.000000     1.000000    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1      Shops_2
# count   2623.000000   5000.00000  5000.000000  5000.000000
# mean    1146.657263      1.31940     4.242800     0.917600
# std     1044.744231      1.47994     4.777365     0.275001
# min        0.000000      0.00000     0.000000     0.000000
# 25%      325.000000      0.00000     1.000000     1.000000
# 50%      900.000000      1.00000     3.000000     1.000000
# 75%     1548.000000      2.00000     6.000000     1.000000
# max     4849.000000      6.00000    23.000000     1.000000

# %%
test.loc[(test.Square > 150) & (test.Square > test.LifeSquare * 2)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1264  13589          27    3.0  173.974480   76.289475            9.0      3
# 2039   3357          27    3.0  170.476326   75.973612            8.0      2
# 3217   4058          27    6.0  223.453689  104.113552           16.0      2
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 1264         3.0       2017   0.041116          1          1        53
# 2039         2.0       2017   0.041116          1          1        53
# 3217         2.0       2017   0.041116          1          1        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# 1264     14892         4           NaN            1        4        1
# 2039     14892         4           NaN            1        4        1
# 3217     14892         4           NaN            1        4        1

# %%
test.loc[(test.Square < 5) & (test.LifeSquare > 30), 'Square'] = test['Square'].mean()

# %%
test.loc[(test.Square * 1.2 < test.LifeSquare) & (test.LifeSquare > 150)] = test['LifeSquare'].mean()

# %%
test.loc[test.Square < test.LifeSquare]
# Out:
#            Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2      5480.0       190.0    1.0  13.597819   15.948246           12.0    2.0
# 27    11160.0        58.0    1.0  48.610661   48.752502            1.0    4.0
# 39     6624.0        27.0    1.0  42.413793   42.434887           10.0   12.0
# 43    11513.0         1.0    1.0  37.484057   40.593036            0.0    4.0
# 70     1872.0        30.0    2.0  52.449057   52.798349            1.0   17.0
# ...       ...         ...    ...        ...         ...            ...    ...
# 4927  14686.0         1.0    3.0  77.229885   79.958685            1.0   18.0
# 4951   3711.0        94.0    1.0  41.281057   42.392594           10.0   13.0
# 4962   5820.0        94.0    1.0  33.680382   34.198977            1.0   10.0
# 4969   4821.0        74.0    2.0  82.542507   82.585069            0.0    4.0
# 4974   5296.0        52.0    1.0  44.442218   44.634608            0.0    5.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 2            5.0     1909.0   0.000000        1.0        1.0      30.0
# 27           3.0     1977.0   0.437885        1.0        1.0      23.0
# 39          17.0     2017.0   0.011654        1.0        1.0       4.0
# 43          17.0     1977.0   0.007122        1.0        1.0       1.0
# 70          17.0     2016.0   0.000078        1.0        1.0      22.0
# ...          ...        ...        ...        ...        ...       ...
# 4927        17.0     1977.0   0.007122        1.0        1.0       1.0
# 4951        13.0     2014.0   0.282798        1.0        1.0      33.0
# 4962         9.0     1972.0   0.127376        1.0        1.0      43.0
# 4969        17.0     2015.0   0.309479        1.0        1.0      35.0
# 4974        17.0     1977.0   0.371149        1.0        1.0      34.0
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# 2       7538.0      87.0        4702.0          5.0      5.0      1.0
# 27      5735.0       3.0        1084.0          0.0      5.0      1.0
# 39       915.0       0.0           NaN          0.0      0.0      1.0
# 43       264.0       0.0           NaN          0.0      1.0      1.0
# 70      6398.0     141.0        1046.0          3.0     23.0      1.0
# ...        ...       ...           ...          ...      ...      ...
# 4927     264.0       0.0           NaN          0.0      1.0      1.0
# 4951    8667.0       2.0           NaN          0.0      6.0      1.0
# 4962    8429.0       3.0           NaN          3.0      9.0      1.0
# 4969    7715.0       4.0         990.0          0.0      6.0      1.0
# 4974    7065.0       1.0         750.0          2.0      5.0      1.0
#
# [240 rows x 19 columns]

# %%
def change_cols(place, col_1, col_2):
    for el in place:
        x1 = test.loc[(test.Id == el), col_1]
        x2 = test.loc[(test.Id == el), col_2]
        test.loc[(test.Id == el), col_1] = x2
        test.loc[(test.Id == el), col_2] = x1

# %%
change_cols(test.loc[test.Square < test.LifeSquare, 'Id'].values, 'Square', 'LifeSquare')

# %%
test.loc[test.KitchenSquare > 200, 'KitchenSquare'] = test['KitchenSquare'].median()

# %%
test.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8410.296032    51.267632     1.917232    56.537841    35.990177
# std     4833.923979    44.175850     0.968040    19.093769    17.172991
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4220.750000    21.000000     1.000000    41.977760    23.092026
# 50%     8319.500000    37.000000     2.000000    52.930550    32.892831
# 75%    12598.250000    77.000000     2.000000    66.392939    45.070420
# max    16795.000000   212.000000    36.158810   223.453689   168.729035
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.860032     8.638232    12.605832  1984.005032     0.127001
# std         4.873548     5.496789     6.797377    33.227471     0.523590
# min         0.000000     1.000000     0.000000    36.158810     0.000000
# 25%         1.000000     4.000000     9.000000  1973.000000     0.019509
# 50%         6.000000     7.000000    12.000000  1977.000000     0.072158
# 75%         9.000000    12.000000    17.000000  2000.000000     0.195781
# max       112.000000    78.000000    99.000000  2020.000000    36.158810
#
#          Ecology_2    Ecology_3     Social_1      Social_2     Social_3  \
# count  5000.000000  5000.000000  5000.000000   5000.000000  5000.000000
# mean      0.997432     0.977232    24.936032   5405.677432     8.269832
# std       0.506827     0.525895    17.532920   4027.317345    23.866736
# min       0.000000     0.000000     0.000000     36.158810     0.000000
# 25%       1.000000     1.000000     6.000000   1564.000000     0.000000
# 50%       1.000000     1.000000    25.000000   5285.000000     2.000000
# 75%       1.000000     1.000000    36.000000   7287.000000     5.000000
# max      36.158810    36.158810    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1      Shops_2
# count   2624.000000  5000.000000  5000.000000  5000.000000
# mean    1146.234054     1.326632     4.250032     0.924632
# std     1044.770003     1.559688     4.798263     0.569221
# min        0.000000     0.000000     0.000000     0.000000
# 25%      325.000000     0.000000     1.000000     1.000000
# 50%      900.000000     1.000000     3.000000     1.000000
# 75%     1548.000000     2.000000     6.000000     1.000000
# max     4849.000000    36.158810    36.158810    36.158810

# %%
test.loc[(test.Floor > test.HouseFloor) & (test.HouseFloor == 0)]
# Out:
#            Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 22    12694.0        27.0    3.0  83.670032   46.358356            0.0    8.0
# 24     8968.0        27.0    2.0  69.849239         NaN            0.0    3.0
# 30     2982.0         6.0    2.0  63.460684         NaN            0.0   13.0
# 32     2449.0         1.0    1.0  66.426585         NaN            0.0   14.0
# 46    12309.0        45.0    1.0  42.899569         NaN            0.0   25.0
# ...       ...         ...    ...        ...         ...            ...    ...
# 4856  10262.0        27.0    2.0  69.196440         NaN            0.0   10.0
# 4887  12116.0        88.0    3.0  89.549559         NaN            0.0   20.0
# 4892  16357.0        58.0    1.0  49.205978         NaN            0.0    4.0
# 4976   4723.0        95.0    1.0  45.542940         NaN            0.0    6.0
# 4998   4780.0        62.0    2.0  81.305222         NaN            0.0    4.0
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 22           0.0     2015.0   0.072158        1.0        1.0       2.0
# 24           0.0     1977.0   0.011654        1.0        1.0       4.0
# 30           0.0     1977.0   0.243205        1.0        1.0       5.0
# 32           0.0     1977.0   0.007122        1.0        1.0       1.0
# 46           0.0     1977.0   0.195781        1.0        1.0      23.0
# ...          ...        ...        ...        ...        ...       ...
# 4856         0.0     1977.0   0.017647        1.0        1.0       2.0
# 4887         0.0     1977.0   0.127376        1.0        1.0      43.0
# 4892         0.0     1977.0   0.437885        1.0        1.0      23.0
# 4976         0.0     1977.0   0.000699        1.0        1.0      14.0
# 4998         0.0     1977.0   0.072158        1.0        1.0       2.0
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# 22       629.0       1.0           NaN          0.0      0.0      0.0
# 24       915.0       0.0           NaN          0.0      0.0      1.0
# 30      1564.0       0.0         540.0          0.0      0.0      1.0
# 32       264.0       0.0           NaN          0.0      1.0      1.0
# 46      5212.0       6.0           NaN          3.0      2.0      1.0
# ...        ...       ...           ...          ...      ...      ...
# 4856     469.0       0.0           NaN          0.0      0.0      1.0
# 4887    8429.0       3.0           NaN          3.0      9.0      1.0
# 4892    5735.0       3.0        1084.0          0.0      5.0      1.0
# 4976    3369.0      24.0        4129.0          0.0      3.0      1.0
# 4998     629.0       1.0           NaN          0.0      0.0      0.0
#
# [131 rows x 19 columns]

# %%
change_cols(test.loc[(test.Floor > test.HouseFloor) & (test.HouseFloor == 0), 'Id'].values, 'Floor', 'HouseFloor')

# %%
import random
wrong_floor = test.loc[test.Floor > test.HouseFloor].index
test.loc[wrong_floor, 'Floor'] = test.loc[wrong_floor, 'HouseFloor'].apply(lambda x: random.randint(1, x))

# %%
test.loc[test.HouseYear < 1900, 'HouseYear'] = test['HouseYear'].mode()[0]

# %%
test.loc[test.KitchenSquare > 50]
# Out:
#            Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  \
# 40     5428.0        27.0    2.0   62.326044         NaN           61.0
# 1456   5260.0        73.0    3.0   69.358242   51.247581           65.0
# 1777   3341.0        62.0    3.0  112.247841  112.114019          112.0
# 3816  12612.0        27.0    2.0   60.988496   33.646726           60.0
# 4281   8015.0        27.0    1.0   66.099096   33.639611           62.0
# 4405   5199.0        27.0    2.0   61.647531   59.054990           57.0
# 4555  12640.0         6.0    2.0   54.629142   31.486308           97.0
#
#       Floor  HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 40     12.0        17.0     1977.0   0.072158        1.0        1.0       2.0
# 1456    6.0         6.0     1931.0   0.042032        1.0        1.0      37.0
# 1777    3.0         3.0     2017.0   0.072158        1.0        1.0       2.0
# 3816    5.0        17.0     2013.0   0.072158        1.0        1.0       2.0
# 4281    3.0         7.0     2016.0   0.014058        1.0        1.0       1.0
# 4405    6.0        12.0     2016.0   0.211401        1.0        1.0       9.0
# 4555    4.0        17.0     2015.0   0.243205        1.0        1.0       5.0
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2
# 40       629.0       1.0           NaN          0.0      0.0      0.0
# 1456    6856.0      84.0        1940.0          2.0      5.0      1.0
# 1777     629.0       1.0           NaN          0.0      0.0      0.0
# 3816     629.0       1.0           NaN          0.0      0.0      0.0
# 4281     290.0       0.0           NaN          0.0      0.0      1.0
# 4405    1892.0       0.0           NaN          0.0      1.0      1.0
# 4555    1564.0       0.0         540.0          0.0      0.0      1.0

# %% [markdown]
# # Столбцы LifeSquare & Healthcare 1 имеют пропуски, заполним их

# %%
test['LifeSquare'].fillna(test['Square']*0.67348861, inplace=True)

# %%
test.loc[(test.Healthcare_1 == 0), 'DistrictId'].value_counts()
# Out:
# 23.0    1
# Name: DistrictId, dtype: int64

# %%
test.loc[(test.DistrictId == 23), 'DistrictId'].value_counts()
# Out:
# 23.0    264
# Name: DistrictId, dtype: int64

# %%
test.loc[(test.Healthcare_1 == 0), 'Healthcare_1'] = np.nan

# %%
healthcare1_mode = test[~test['Healthcare_1'].isna()]['Healthcare_1'].mode()[0]
for i in range(212):
    if test.loc[(test['DistrictId'] == i), 'Healthcare_1'].value_counts().empty:
        health_mode = healthcare1_mode
    else:
        health_mode = test.loc[((test.DistrictId == i)&(~test.DistrictId.isna())), 'Healthcare_1'].mode()[0]
    test.loc[((test['Healthcare_1'].isnull())&(test['DistrictId'] == i)), 'Healthcare_1'] = health_mode
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   float64
#  1   DistrictId     5000 non-null   float64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     5000 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   float64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   float64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   float64
#  11  Ecology_3      5000 non-null   float64
#  12  Social_1       5000 non-null   float64
#  13  Social_2       5000 non-null   float64
#  14  Social_3       5000 non-null   float64
#  15  Healthcare_1   5000 non-null   float64
#  16  Helthcare_2    5000 non-null   float64
#  17  Shops_1        5000 non-null   float64
#  18  Shops_2        5000 non-null   float64
# dtypes: float64(19)
# memory usage: 742.3 KB

# %%
test = test.iloc[:, 2:]

# %%
test_scaled = scaler.transform(test)
test_scaled = pd.DataFrame(test_scaled, columns=test.columns)

# %%
test_scaled
# Out:
#          Rooms    Square  LifeSquare  KitchenSquare     Floor  HouseFloor  \
# 0     0.140728 -0.318058   -0.200076       0.015826 -0.236691    0.167094
# 1     0.140728  0.626259    0.541067      -0.918906 -1.205827   -1.798214
# 2    -1.090644 -1.971511   -1.312474       1.137506 -1.012000   -1.193504
# 3     0.140728  0.810606    0.837906       0.576666  2.864546    1.376515
# 4    -1.090644 -0.432831    0.358215      -0.918906  1.895410    0.620627
# ...        ...       ...         ...            ...       ...         ...
# 4995  1.372100  0.522510    0.774474       0.015826 -0.430518   -0.588793
# 4996 -1.090644 -0.789919   -0.852078       0.763613  0.926273    0.620627
# 4997  1.372100  1.044270    0.632743       0.576666 -0.236691    1.376515
# 4998  0.140728  1.213007    0.995907      -1.105853 -1.399655   -1.344681
# 4999  0.140728  0.201986    0.212176      -0.918906  0.538618    0.620627
#
#       HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  Social_2  \
# 0     -0.705631   1.622043   0.096058   0.172379 -0.783021 -0.652234
# 1     -0.432530  -0.354673   0.096058   0.172379 -1.067393 -0.979046
# 2     -4.146708  -0.993666   0.096058   0.172379  0.297591  0.541838
# 3      1.206078  -0.134641   0.096058   0.172379 -0.100529 -0.194797
# 4      1.752280  -0.385208   0.096058   0.172379 -1.294890 -1.180468
# ...         ...        ...        ...        ...       ...       ...
# 4995  -0.651011  -0.992235   0.096058   0.172379  0.638837  0.156445
# 4996   1.752280  -0.933608   0.096058   0.172379 -1.351764 -1.271457
# 4997   0.222913  -0.228016   0.096058   0.172379  2.800060  3.419827
# 4998  -0.432530  -0.385208   0.096058   0.172379 -1.294890 -1.180468
# 4999  -0.432530  -0.993007   0.096058   0.172379 -0.157404  0.257654
#
#       Social_3  Healthcare_1  Helthcare_2   Shops_1   Shops_2
# 0    -0.295144      0.122668    -0.882358 -0.883079  0.301699
# 1    -0.211351      0.019141    -0.882358 -0.468543  0.301699
# 2     3.307966      4.107367     2.477360  0.153260  0.301699
# 3    -0.211351     -0.806875     1.133473 -0.261276  0.301699
# 4    -0.295144     -0.476468    -0.882358 -0.883079 -3.314559
# ...        ...           ...          ...       ...       ...
# 4995 -0.337040      0.046675    -0.210414 -0.675811  0.301699
# 4996 -0.337040     -0.806875    -0.882358 -0.675811  0.301699
# 4997 -0.253247     -0.476468     2.477360  2.225936  0.301699
# 4998 -0.295144      1.461915    -0.882358 -0.883079 -3.314559
# 4999  5.570384      0.080817     1.133473  3.884077  0.301699
#
# [5000 rows x 17 columns]

# %%
y_predict = boost_best.predict(test_scaled)
y_predict
# Out:
# array([143321.91275738, 210248.3857109 , 206132.02080832, ...,
#        323278.02734541, 186672.55781257, 190587.00627325])

# %%
ABorodin_predicts = pd.DataFrame({'Id':test_id,
                       'Price':y_predict}, columns=['Id', 'Price'])
ABorodin_predicts
# Out:
#          Id          Price
# 0       725  143321.912757
# 1     15856  210248.385711
# 2      5480  206132.020808
# 3     15664  338964.622128
# 4     14275  143095.629909
# ...     ...            ...
# 4995   8180  221168.712239
# 4996   4695  144263.516855
# 4997   5783  323278.027345
# 4998   4780  186672.557813
# 4999  12504  190587.006273
#
# [5000 rows x 2 columns]

# %%
ABorodin_predicts.to_csv('ABorodin_predictions_1.csv', index=False)
